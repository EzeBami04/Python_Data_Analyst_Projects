# %% [markdown]
# # Reading in Files

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\Scripts.py\Companies.csv", sep = ',')

df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and Cloud Computing
# 2      3               Exxon Mobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289          6.70%  2,100,000    Bentonville, Arkansas
# ...

# %%
df1 = pd.read_excel(r"C:\Users\USER\OneDrive\Excel Files\Sales Data Dashboard new (Recovered).xlsx",sheet_name = 'Sales')

df1
# Out:
#              Date  Day     Month  Year  Customer_Age Age Group  \
# 0      2013-11-26   26  November  2013            19     Youth
# 1      2015-11-26   26  November  2015            19     Youth
# 2      2014-03-23   23     March  2014            49    Adults
# 3      2016-03-23   23     March  2016            49    Adults
# 4      2014-05-15   15       May  2014            47    Adults
# ...           ...  ...       ...   ...           ...       ...
# 112031 2016-04-12   12     April  2016            41    Adults
# 112032 2014-04-02    2     April  2014            18     Youth
# 112033 2016-04-02    2     April  2016            18     Youth
# 112034 2014-03-04    4     March  2014            37    Adults
# 112035 2016-03-04    4     March  2016            37    Adults
#
#        CustoMaleer_Gender         Country             State Product_Category  \
# 0                    Male          Canada  British Columbia      Accessories
# ...

# %%
pd.set_option('display.max.rows', 500)

# %%
df1 = pd.read_excel(r"C:\Users\USER\OneDrive\Excel Files\Sales Data Dashboard new (Recovered).xlsx",sheet_name = 'Sales')

df1
# Out:
#              Date  Day     Month  Year  Customer_Age Age Group  \
# 0      2013-11-26   26  November  2013            19     Youth
# 1      2015-11-26   26  November  2015            19     Youth
# 2      2014-03-23   23     March  2014            49    Adults
# 3      2016-03-23   23     March  2016            49    Adults
# 4      2014-05-15   15       May  2014            47    Adults
# ...           ...  ...       ...   ...           ...       ...
# 112031 2016-04-12   12     April  2016            41    Adults
# 112032 2014-04-02    2     April  2014            18     Youth
# 112033 2016-04-02    2     April  2016            18     Youth
# 112034 2014-03-04    4     March  2014            37    Adults
# 112035 2016-03-04    4     March  2016            37    Adults
#
#        CustoMaleer_Gender         Country             State Product_Category  \
# 0                    Male          Canada  British Columbia      Accessories
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112036 entries, 0 to 112035
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                112036 non-null  datetime64[ns]
#  1   Day                 112036 non-null  int64
#  2   Month               112036 non-null  object
#  3   Year                112036 non-null  int64
#  4   Customer_Age        112036 non-null  int64
#  5   Age Group           112036 non-null  object
#  6   CustoMaleer_Gender  112036 non-null  object
#  7   Country             112036 non-null  object
#  8   State               112036 non-null  object
#  9   Product_Category    112036 non-null  object
#  10  Sub_Category        112036 non-null  object
#  11  Product             112036 non-null  object
#  12  Order_Quantity      112036 non-null  int64
#  13  Unit_Cost           112036 non-null  int64
#  14  Unit_Price          112036 non-null  int64
# ...

# %%
df1.shape
# Out:
# (112036, 18)

# %%
df1.head(50)
# Out:
#          Date  Day      Month  Year  Customer_Age     Age Group  \
# 0  2013-11-26   26   November  2013            19         Youth
# 1  2015-11-26   26   November  2015            19         Youth
# 2  2014-03-23   23      March  2014            49        Adults
# 3  2016-03-23   23      March  2016            49        Adults
# 4  2014-05-15   15        May  2014            47        Adults
# 5  2016-05-15   15        May  2016            47        Adults
# 6  2014-05-22   22        May  2014            47        Adults
# 7  2016-05-22   22        May  2016            47        Adults
# 8  2014-02-22   22   February  2014            35        Adults
# 9  2016-02-22   22   February  2016            35        Adults
# 10 2013-07-30   30       July  2013            32  Young Adults
# 11 2015-07-30   30       July  2015            32  Young Adults
# 12 2013-07-15   15       July  2013            34  Young Adults
# 13 2015-07-15   15       July  2015            34  Young Adults
# ...

# %%
df1.loc[500]
# Out:
# Date                  2014-02-28 00:00:00
# Day                                    28
# Month                            February
# Year                                 2014
# Customer_Age                           22
# Age Group                           Youth
# CustoMaleer_Gender                 Female
# Country                           Germany
# State                            Saarland
# Product_Category              Accessories
# Sub_Category                   Bike Racks
# Product               Hitch Rack - 4-Bike
# Order_Quantity                          3
# Unit_Cost                              45
# Unit_Price                            120
# Profit                                160
# Cost                                  135
# Revenue                               295
# Name: 500, dtype: object

# %%
df1.iloc[500]
# Out:
# Date                  2014-02-28 00:00:00
# Day                                    28
# Month                            February
# Year                                 2014
# Customer_Age                           22
# Age Group                           Youth
# CustoMaleer_Gender                 Female
# Country                           Germany
# State                            Saarland
# Product_Category              Accessories
# Sub_Category                   Bike Racks
# Product               Hitch Rack - 4-Bike
# Order_Quantity                          3
# Unit_Cost                              45
# Unit_Price                            120
# Profit                                160
# Cost                                  135
# Revenue                               295
# Name: 500, dtype: object

# %% [markdown]
# ## Filtering Data Within Pandas

# %%
df
# Out:
#                                      Name Revenue (USD millions)  \
# Rank
# 1                                 Walmart                611,289
# 2                                  Amazon                513,983
# 3                             Exxon Mobil                413,680
# 4                                   Apple                394,328
# 5                      UnitedHealth Group                324,162
# 6                              CVS Health                322,467
# 7                      Berkshire Hathaway                302,089
# 8                                Alphabet                282,836
# 9                    McKesson Corporation                276,711
# 10                    Chevron Corporation                246,252
# 11                      AmerisourceBergen                238,587
# 12                                 Costco                226,954
# 13                              Microsoft                198,270
# ...

# %%
df[df['Rank'] < 50]
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and Cloud Computing
# 2      3               Exxon Mobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# 5      6                CVS Health                  Healthcare
# 6      7        Berkshire Hathaway                Conglomerate
# 7      8                  Alphabet                  Technology
# 8      9      McKesson Corporation                      Health
# 9     10       Chevron Corporation          Petroleum industry
# 10    11         AmerisourceBergen     Pharmaceutical industry
# 11    12                    Costco                      Retail
# 12    13                 Microsoft                  Technology
# 13    14           Cardinal Health                  Healthcare
# ...

# %%
specific_industry = ['Retail', 'Electronics industry']

df[df['Industry'].isin(specific_industry)]
# Out:
#     Rank                Name              Industry Revenue (USD millions)  \
# 0      1             Walmart                Retail                611,289
# 3      4               Apple  Electronics industry                394,328
# 11    12              Costco                Retail                226,954
# 19    20      The Home Depot                Retail                157,403
# 23    24              Kroger                Retail                148,258
# 32    33  Target Corporation                Retail                109,120
# 38    39              Lowe's                Retail                 97,059
# 52    53          Albertsons                Retail                 77,650
# 79    80              Publix                Retail                 54,942
# 88    89                 TJX                Retail                 49,936
# 95    96            Best Buy                Retail                 46,298
#
#    Revenue growth  Employees                 Headquarters
# ...

# %%
df[df['Industry'].str.contains('Electronics industry')]
# Out:
#    Rank   Name              Industry Revenue (USD millions) Revenue growth  \
# 3     4  Apple  Electronics industry                394,328          7.80%
#
#   Employees           Headquarters
# 3   164,000  Cupertino, California

# %% [markdown]
# ## Filtering on index

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Rank                                 Name Revenue (USD millions)  \
# 0      1                              Walmart                611,289
# 1      2                               Amazon                513,983
# 2      3                          Exxon Mobil                413,680
# 3      4                                Apple                394,328
# 4      5                   UnitedHealth Group                324,162
# 5      6                           CVS Health                322,467
# 6      7                   Berkshire Hathaway                302,089
# 7      8                             Alphabet                282,836
# 8      9                 McKesson Corporation                276,711
# 9     10                  Chevron Corporation                246,252
# 10    11                    AmerisourceBergen                238,587
# 11    12                               Costco                226,954
# 12    13                            Microsoft                198,270
# ...

# %%
df = df.set_index('Rank')
df
# Out:
#                                      Name Revenue (USD millions)  \
# Rank
# 1                                 Walmart                611,289
# 2                                  Amazon                513,983
# 3                             Exxon Mobil                413,680
# 4                                   Apple                394,328
# 5                      UnitedHealth Group                324,162
# 6                              CVS Health                322,467
# 7                      Berkshire Hathaway                302,089
# 8                                Alphabet                282,836
# 9                    McKesson Corporation                276,711
# 10                    Chevron Corporation                246,252
# 11                      AmerisourceBergen                238,587
# 12                                 Costco                226,954
# 13                              Microsoft                198,270
# ...

# %%
df.filter(items = ['Headquarters', 'Revenue growth'], axis = 1)
# Out:
#                                     Headquarters Revenue growth
# Rank
# 1                          Bentonville, Arkansas          6.70%
# 2                            Seattle, Washington          9.40%
# 3                                  Spring, Texas         44.80%
# 4                          Cupertino, California          7.80%
# 5                          Minnetonka, Minnesota         12.70%
# 6                       Woonsocket, Rhode Island         10.40%
# 7                                Omaha, Nebraska          9.40%
# 8                      Mountain View, California          9.80%
# 9                                  Irving, Texas          4.80%
# 10                         San Ramon, California         51.60%
# 11                    Chesterbrook, Pennsylvania         11.50%
# 12                          Issaquah, Washington         15.80%
# 13                           Redmond, Washington         18.00%
# 14                                  Dublin, Ohio         11.60%
# ...

# %%
df.loc[40]
# Out:
# Name                              Johnson & Johnson
# Revenue (USD millions)                       94,943
# Revenue growth                                1.20%
# Employees                                   152,700
# Headquarters              New Brunswick, New Jersey
# Name: 40, dtype: object

# %%
df.iloc[90]
# Out:
# Name                      American Airlines
# Revenue (USD millions)               48,971
# Revenue growth                       63.90%
# Employees                           129,700
# Headquarters              Fort Worth, Texas
# Name: 91, dtype: object

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ## Order by in Python

# %%
df[df['Rank'] < 50].sort_values(by= ('Rank'),ascending=True)
# Out:
#     Rank                      Name Revenue (USD millions) Revenue growth  \
# 0      1                   Walmart                611,289          6.70%
# 1      2                    Amazon                513,983          9.40%
# 2      3               Exxon Mobil                413,680         44.80%
# 3      4                     Apple                394,328          7.80%
# 4      5        UnitedHealth Group                324,162         12.70%
# 5      6                CVS Health                322,467         10.40%
# 6      7        Berkshire Hathaway                302,089          9.40%
# 7      8                  Alphabet                282,836          9.80%
# 8      9      McKesson Corporation                276,711          4.80%
# 9     10       Chevron Corporation                246,252         51.60%
# 10    11         AmerisourceBergen                238,587         11.50%
# 11    12                    Costco                226,954         15.80%
# ...

# %%
df[df['Rank'] < 50].sort_values(by=['Rank','Name'], ascending=[True,False])
# Out:
#     Rank                      Name Revenue (USD millions) Revenue growth  \
# 0      1                   Walmart                611,289          6.70%
# 1      2                    Amazon                513,983          9.40%
# 2      3               Exxon Mobil                413,680         44.80%
# 3      4                     Apple                394,328          7.80%
# 4      5        UnitedHealth Group                324,162         12.70%
# 5      6                CVS Health                322,467         10.40%
# 6      7        Berkshire Hathaway                302,089          9.40%
# 7      8                  Alphabet                282,836          9.80%
# 8      9      McKesson Corporation                276,711          4.80%
# 9     10       Chevron Corporation                246,252         51.60%
# 10    11         AmerisourceBergen                238,587         11.50%
# 11    12                    Costco                226,954         15.80%
# ...

# %% [markdown]
# ## Indexing

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\Scripts.py\Companies.csv", index_col = 'Industry')
df
# Out:
#                             Rank                      Name  \
# Industry
# Retail                         1                   Walmart
# Retail and Cloud Computing     2                    Amazon
# Petroleum industry             3               Exxon Mobil
# Electronics industry           4                     Apple
# Healthcare                     5        UnitedHealth Group
# ...                          ...                       ...
# Retail                        96                  Best Buy
# Pharmaceutical industry       97      Bristol-Myers Squibb
# Airline                       98           United Airlines
# Laboratory instruments        99  Thermo Fisher Scientific
# Technology                   100                  Qualcomm
#
#                            Revenue (USD millions) Revenue growth  Employees  \
# Industry
# Retail                                    611,289          6.70%  2,100,000
# Retail and Cloud Computing                513,983          9.40%  1,540,000
# ...

# %%
df
# Out:
#     Rank                                 Name Revenue (USD millions)  \
# 0      1                              Walmart                611,289
# 1      2                               Amazon                513,983
# 2      3                          Exxon Mobil                413,680
# 3      4                                Apple                394,328
# 4      5                   UnitedHealth Group                324,162
# 5      6                           CVS Health                322,467
# 6      7                   Berkshire Hathaway                302,089
# 7      8                             Alphabet                282,836
# 8      9                 McKesson Corporation                276,711
# 9     10                  Chevron Corporation                246,252
# 10    11                    AmerisourceBergen                238,587
# 11    12                               Costco                226,954
# 12    13                            Microsoft                198,270
# ...

# %%
df1.loc['Retail']
# Out:
#           Rank                Name Revenue (USD millions) Revenue growth  \
# Industry
# Retail       1             Walmart                611,289          6.70%
# Retail      12              Costco                226,954         15.80%
# Retail      20      The Home Depot                157,403          4.10%
# Retail      24              Kroger                148,258          7.50%
# Retail      33  Target Corporation                109,120          2.90%
# Retail      39              Lowe's                 97,059          0.80%
# Retail      53          Albertsons                 77,650          8.00%
# Retail      80              Publix                 54,942         13.50%
# Retail      89                 TJX                 49,936          2.90%
# Retail      96            Best Buy                 46,298         10.60%
#
#           Employees                 Headquarters
# Industry
# Retail    2,100,000        Bentonville, Arkansas
# ...

# %%
df.iloc[1]
# Out:
# Rank                                        2
# Name                                   Amazon
# Revenue (USD millions)                513,983
# Revenue growth                          9.40%
# Employees                           1,540,000
# Headquarters              Seattle, Washington
# Name: 1, dtype: object

# %% [markdown]
# ## multi Index

# %%
df.set_index('Rank', inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.set_index(['Name', 'Industry'], inplace=True)

df
# Out:
#                                                                       Rank  \
# Name                                Industry
# Walmart                             Retail                               1
# Amazon                              Retail and Cloud Computing           2
# Exxon Mobil                         Petroleum industry                   3
# Apple                               Electronics industry                 4
# UnitedHealth Group                  Healthcare                           5
# CVS Health                          Healthcare                           6
# Berkshire Hathaway                  Conglomerate                         7
# Alphabet                            Technology                           8
# McKesson Corporation                Health                               9
# Chevron Corporation                 Petroleum industry                  10
# AmerisourceBergen                   Pharmaceutical industry             11
# ...

# %%
df.sort_index()
# Out:
#                                                                       Rank  \
# Name                                Industry
# AIG                                 Insurance                           78
# AT&T                                Conglomerate                        30
# AbbVie                              Pharmaceutical industry             75
# Albertsons                          Retail                              53
# Allstate                            Insurance                           86
# Alphabet                            Technology                           8
# Amazon                              Retail and Cloud Computing           2
# American Airlines                   Airline                             91
# American Express                    Financial                           79
# AmerisourceBergen                   Pharmaceutical industry             11
# Apple                               Electronics industry                 4
# ...

# %%
df1.set_index(['Country', 'State'], inplace=True)

# %%
df1
# Out:
#                                       Date  Day     Month  Year  Customer_Age  \
# Country        State
# Canada         British Columbia 2013-11-26   26  November  2013            19
#                British Columbia 2015-11-26   26  November  2015            19
# Australia      New South Wales  2014-03-23   23     March  2014            49
#                New South Wales  2016-03-23   23     March  2016            49
#                New South Wales  2014-05-15   15       May  2014            47
# ...                                    ...  ...       ...   ...           ...
# United Kingdom England          2016-04-12   12     April  2016            41
# Australia      Queensland       2014-04-02    2     April  2014            18
#                Queensland       2016-04-02    2     April  2016            18
# France         Seine (Paris)    2014-03-04    4     March  2014            37
#                Seine (Paris)    2016-03-04    4     March  2016            37
#
# ...

# %%
df1.sort_index(ascending=[True,False])

#pd.set_option('display.max.rows', 200)
# Out:
#                              Date  Day     Month  Year  Customer_Age  \
# Country       State
# Australia     Victoria 2014-05-22   22       May  2014            47
#               Victoria 2016-05-22   22       May  2016            47
#               Victoria 2014-02-22   22  February  2014            35
#               Victoria 2016-02-22   22  February  2016            35
#               Victoria 2013-07-30   30      July  2013            32
# ...                           ...  ...       ...   ...           ...
# United States Arizona  2015-10-05    5   October  2015            24
#               Alabama  2013-11-15   15  November  2013            40
#               Alabama  2015-11-15   15  November  2015            40
#               Alabama  2014-07-13   13      July  2014            40
#               Alabama  2016-07-13   13      July  2016            40
#
#                            Age Group CustoMaleer_Gender Product_Category  \
# Country       State
# ...

# %%
df1
# Out:
#                                       Date  Day     Month  Year  Customer_Age  \
# Country        State
# Canada         British Columbia 2013-11-26   26  November  2013            19
#                British Columbia 2015-11-26   26  November  2015            19
# Australia      New South Wales  2014-03-23   23     March  2014            49
#                New South Wales  2016-03-23   23     March  2016            49
#                New South Wales  2014-05-15   15       May  2014            47
# ...                                    ...  ...       ...   ...           ...
# United Kingdom England          2016-04-12   12     April  2016            41
# Australia      Queensland       2014-04-02    2     April  2014            18
#                Queensland       2016-04-02    2     April  2016            18
# France         Seine (Paris)    2014-03-04    4     March  2014            37
#                Seine (Paris)    2016-03-04    4     March  2016            37
#
# ...

# %%
df1.loc['Australia']
# Out:
#                       Date  Day    Month  Year  Customer_Age     Age Group  \
# State
# New South Wales 2014-03-23   23    March  2014            49        Adults
# New South Wales 2016-03-23   23    March  2016            49        Adults
# New South Wales 2014-05-15   15      May  2014            47        Adults
# New South Wales 2016-05-15   15      May  2016            47        Adults
# Victoria        2014-05-22   22      May  2014            47        Adults
# ...                    ...  ...      ...   ...           ...           ...
# New South Wales 2016-04-06    6    April  2016            58        Adults
# Victoria        2014-01-18   18  January  2014            32  Young Adults
# Victoria        2016-01-18   18  January  2016            32  Young Adults
# Queensland      2014-04-02    2    April  2014            18         Youth
# Queensland      2016-04-02    2    April  2016            18         Youth
#
# ...

# %%
df.iloc[2]
# Out:
# Rank                                  3
# Revenue (USD millions)          413,680
# Revenue growth                   44.80%
# Employees                        62,000
# Headquarters              Spring, Texas
# Name: (Exxon Mobil, Petroleum industry), dtype: object
