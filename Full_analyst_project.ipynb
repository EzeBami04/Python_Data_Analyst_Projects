# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings

# %%
df = pd.read_excel(r"C:\Users\USER\Desktop\Pythonfile.py\Sales.xlsx", sheet_name ='Sales')
df
# Out:
#              Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0      2013-11-26   26  November  2013            19     Youth (<25)
# 1      2015-11-26   26  November  2015            19     Youth (<25)
# 2      2014-03-23   23     March  2014            49  Adults (35-64)
# 3      2016-03-23   23     March  2016            49  Adults (35-64)
# 4      2014-05-15   15       May  2014            47  Adults (35-64)
# ...           ...  ...       ...   ...           ...             ...
# 113031 2016-04-12   12     April  2016            41  Adults (35-64)
# 113032 2014-04-02    2     April  2014            18     Youth (<25)
# 113033 2016-04-02    2     April  2016            18     Youth (<25)
# 113034 2014-03-04    4     March  2014            37  Adults (35-64)
# 113035 2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#              Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0      2013-11-26   26  November  2013            19     Youth (<25)
# 1      2015-11-26   26  November  2015            19     Youth (<25)
# 2      2014-03-23   23     March  2014            49  Adults (35-64)
# 3      2016-03-23   23     March  2016            49  Adults (35-64)
# 4      2014-05-15   15       May  2014            47  Adults (35-64)
# ...           ...  ...       ...   ...           ...             ...
# 113031 2016-04-12   12     April  2016            41  Adults (35-64)
# 113032 2014-04-02    2     April  2014            18     Youth (<25)
# 113033 2016-04-02    2     April  2016            18     Youth (<25)
# 113034 2014-03-04    4     March  2014            37  Adults (35-64)
# 113035 2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df = df.drop(columns= [ 'Day', 'Month', 'Year','Customer_Age','Sub_Category', 'Age_Group','Customer_Gender'])
df
# Out:
#              Date         Country             State Product_Category  \
# 0      2013-11-26          Canada  British Columbia      Accessories
# 1      2015-11-26          Canada  British Columbia      Accessories
# 2      2014-03-23       Australia   New South Wales      Accessories
# 3      2016-03-23       Australia   New South Wales      Accessories
# 4      2014-05-15       Australia   New South Wales      Accessories
# ...           ...             ...               ...              ...
# 113031 2016-04-12  United Kingdom           England         Clothing
# 113032 2014-04-02       Australia        Queensland         Clothing
# 113033 2016-04-02       Australia        Queensland         Clothing
# 113034 2014-03-04          France     Seine (Paris)         Clothing
# 113035 2016-03-04          France     Seine (Paris)         Clothing
#
#                     Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112036 entries, 0 to 113035
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              112036 non-null  datetime64[ns]
#  1   Country           112036 non-null  object
#  2   State             112036 non-null  object
#  3   Product_Category  112036 non-null  object
#  4   Product           112036 non-null  object
#  5   Order_Quantity    112036 non-null  int64
#  6   Unit_Cost         112036 non-null  int64
#  7   Unit_Price        112036 non-null  int64
#  8   Profit            112036 non-null  int64
#  9   Cost              112036 non-null  int64
#  10  Revenue           112036 non-null  int64
# dtypes: datetime64[ns](1), int64(6), object(4)
# memory usage: 10.3+ MB

# %%
df = df.reset_index(drop=True)
df
# Out:
#              Date         Country             State Product_Category  \
# 0      2013-11-26          Canada  British Columbia      Accessories
# 1      2015-11-26          Canada  British Columbia      Accessories
# 2      2014-03-23       Australia   New South Wales      Accessories
# 3      2016-03-23       Australia   New South Wales      Accessories
# 4      2014-05-15       Australia   New South Wales      Accessories
# ...           ...             ...               ...              ...
# 112031 2016-04-12  United Kingdom           England         Clothing
# 112032 2014-04-02       Australia        Queensland         Clothing
# 112033 2016-04-02       Australia        Queensland         Clothing
# 112034 2014-03-04          France     Seine (Paris)         Clothing
# 112035 2016-03-04          France     Seine (Paris)         Clothing
#
#                     Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# ...

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df2 = df.filter(items= ["Country", "Revenue", "Profit"], axis = 1)
df
# Out:
#              Date         Country             State Product_Category  \
# 0      2013-11-26          Canada  British Columbia      Accessories
# 1      2015-11-26          Canada  British Columbia      Accessories
# 2      2014-03-23       Australia   New South Wales      Accessories
# 3      2016-03-23       Australia   New South Wales      Accessories
# 4      2014-05-15       Australia   New South Wales      Accessories
# ...           ...             ...               ...              ...
# 112031 2016-04-12  United Kingdom           England         Clothing
# 112032 2014-04-02       Australia        Queensland         Clothing
# 112033 2016-04-02       Australia        Queensland         Clothing
# 112034 2014-03-04          France     Seine (Paris)         Clothing
# 112035 2016-03-04          France     Seine (Paris)         Clothing
#
#                     Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# ...

# %%
group_df2_frame = df2.groupby("Country")

# %%
df2 = group_df2_frame.sum()
df2
# Out:
#                  Revenue    Profit
# Country
# Australia       21196395   6740522
# Canada           7906182   3702019
# France           8414745   2872082
# Germany          8956724   3349991
# United Kingdom  10575628   4383987
# United States   27777098  10997638

# %%
df2.plot.barh(stacked=True, figsize= (20,7))
# Out:
# <Axes: ylabel='Country'>

# %%
df3 = df.filter(items= ["State", "Profit", "Revenue"])
df3
# Out:
#                    State  Profit  Revenue
# 0       British Columbia     590      950
# 1       British Columbia     590      950
# 2        New South Wales    1366     2401
# 3        New South Wales    1188     2088
# 4        New South Wales     238      418
# ...                  ...     ...      ...
# 113031           England     112      184
# 113032        Queensland     655     1183
# 113033        Queensland     655     1183
# 113034     Seine (Paris)     684     1260
# 113035     Seine (Paris)     655     1207
#
# [113036 rows x 3 columns]

# %%
group_df3_frame = df3.groupby("State")

# %%
df3 = group_df3_frame.sum()
df3
# Out:
#                       Profit   Revenue
# State
# Alabama                  105       210
# Alberta                23350     56803
# Arizona                 4279      9379
# Bayern                576691   1341985
# Brandenburg            71352    169770
# British Columbia     3693348   7877890
# California           7772869  17672620
# Charente-Maritime      46000    106047
# England              4413853  10646196
# Essonne               393848    973532
# Florida                 4700     11014
# Garonne (Haute)        72947    183906
# Georgia                 1947      4862
# Hamburg               616499   1559005
# Hauts de Seine        364137    937140
# Hessen                813402   2073391
# Illinois                8606     20141
# Kentucky                2216      3756
# Loir et Cher           32761     82533
# Loiret                118491    325172
# Massachusetts           1552      4084
# Minnesota                228      1466
# Mississippi              322      1684
# ...

# %%
df3.plot.bar(y= ['Profit','Revenue'], stacked=True, figsize= (20,10))
# Out:
# <Axes: xlabel='State'>

# %%
df4 = df.filter(items= ["Product_Category", "Profit", "Revenue"])
df4
# Out:
#        Product_Category  Profit  Revenue
# 0           Accessories     590      950
# 1           Accessories     590      950
# 2           Accessories    1366     2401
# 3           Accessories    1188     2088
# 4           Accessories     238      418
# ...                 ...     ...      ...
# 113031         Clothing     112      184
# 113032         Clothing     655     1183
# 113033         Clothing     655     1183
# 113034         Clothing     684     1260
# 113035         Clothing     655     1207
#
# [113036 rows x 3 columns]

# %%
group_df4_frame = df4.groupby('Product_Category')

# %%
df4 = group_df4_frame.sum()
df4
# Out:
#                     Profit   Revenue
# Product_Category
# Accessories        8862377  15117992
# Bikes             20519276  61782134
# Clothing           2839447   8370882

# %%
df4.boxplot()
# Out:
# <Axes: >
